# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

tweets = []
try:
    for line in open('tweets.txt', 'r'):
        if line.strip():
            tweets.append(json.loads(line))
    
except ValueError as detail:  # includes simplejson.decoder.JSONDecodeError
    print 'Decoding JSON has failed', detail

# %%
texts = [tweet['tweet']['text'] for tweet in tweets]
import time
times = []
for tweet in tweets:
    #times.append(tweet['tweet']['text'])
    times.append(time.strftime('%Y-%m-%d', time.localtime(tweet['firstpost_date'])))

# %%
import re

liecounts = []
try:
    for line in texts:
        liecounts.append(line.count('lie', re.IGNORECASE))
        
except ValueError as detail:  
    print 'fail?', detail
    
print len(liecounts)

flopcounts = []
try:
    for line in texts:
        flopcounts.append(line.count('flop', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(flopcounts)



jokecounts = []
try:
    for line in texts:
        jokecounts.append(line.count('joke', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(jokecounts)

credcounts = []
try:
    for line in texts:
        credcounts.append(line.count('credibility', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(credcounts)
accuracycounts = []
try:
    for line in texts:
        accuracycounts.append(line.count('accuracy', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(accuracycounts)
disbeliefcounts = []
try:
    for line in texts:
        disbeliefcounts.append(line.count('disbelief', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(disbeliefcounts)
discreditcounts = []
try:
    for line in texts:
        discreditcounts.append(line.count('discredit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(discreditcounts)
rejectcounts = []
try:
    for line in texts:
        rejectcounts.append(line.count('reject', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(rejectcounts)
falsehoodcounts = []
try:
    for line in texts:
        falsehoodcounts.append(line.count('falsehood', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(falsehoodcounts)
impostercounts = []
try:
    for line in texts:
        impostercounts.append(line.count('imposter', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(impostercounts)
fakecounts = []
try:
    for line in texts:
        fakecounts.append(line.count('fake', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fakecounts)
FALSEcounts = []
try:
    for line in texts:
        FALSEcounts.append(line.count('FALSE', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(FALSEcounts)
insincerecounts = []
try:
    for line in texts:
        insincerecounts.append(line.count('insincere', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(insincerecounts)
deceivecounts = []
try:
    for line in texts:
        deceivecounts.append(line.count('deceive', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(deceivecounts)
notgenuinecounts = []
try:
    for line in texts:
        notgenuinecounts.append(line.count('not genuine', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(notgenuinecounts)
nottruecounts = []
try:
    for line in texts:
        nottruecounts.append(line.count('not true', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(nottruecounts)
undependablecounts = []
try:
    for line in texts:
        undependablecounts.append(line.count('undependable', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(undependablecounts)
unreliablecounts = []
try:
    for line in texts:
        unreliablecounts.append(line.count('unreliable', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(unreliablecounts)
prevaricationcounts = []
try:
    for line in texts:
        prevaricationcounts.append(line.count('prevarication', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(prevaricationcounts)
bustcounts = []
try:
    for line in texts:
        bustcounts.append(line.count('bust', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(bustcounts)
gagcounts = []
try:
    for line in texts:
        gagcounts.append(line.count('gag', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(gagcounts)
crediblenesscounts = []
try:
    for line in texts:
        crediblenesscounts.append(line.count('credibleness', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(crediblenesscounts)

truthcounts = []
try:
    for line in texts:
        truthcounts.append(line.count('truth', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(truthcounts)

falsitycounts = []
try:
    for line in texts:
        falsitycounts.append(line.count('falsity', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(falsitycounts)

impostorcounts = []
try:
    for line in texts:
        impostorcounts.append(line.count('impostor', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(impostorcounts)

fauxcounts = []
try:
    for line in texts:
        fauxcounts.append(line.count('faux', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fauxcounts)

shamcounts = []
try:
    for line in texts:
        shamcounts.append(line.count('sham', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(shamcounts)

leadoncounts = []
try:
    for line in texts:
        leadoncounts.append(line.count('lead on', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(leadoncounts)

fizzlecounts = []
try:
    for line in texts:
        fizzlecounts.append(line.count('fizzle', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fizzlecounts)

laughcounts = []
try:
    for line in texts:
        laughcounts.append(line.count('laugh', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(laughcounts)

believabilitycounts = []
try:
    for line in texts:
        believabilitycounts.append(line.count('believability', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(believabilitycounts)

untruthcounts = []
try:
    for line in texts:
        untruthcounts.append(line.count('untruth', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(untruthcounts)

pretendercounts = []
try:
    for line in texts:
        pretendercounts.append(line.count('pretender', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(pretendercounts)

imitationcounts = []
try:
    for line in texts:
        imitationcounts.append(line.count('imitation', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(imitationcounts)

postichecounts = []
try:
    for line in texts:
        postichecounts.append(line.count('postiche', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(postichecounts)

deludecounts = []
try:
    for line in texts:
        deludecounts.append(line.count('delude', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(deludecounts)

simulatedcounts = []
try:
    for line in texts:
        simulatedcounts.append(line.count('simulated', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(simulatedcounts)

japecounts = []
try:
    for line in texts:
        japecounts.append(line.count('jape', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(japecounts)

fraudcounts = []
try:
    for line in texts:
        fraudcounts.append(line.count('fraud', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fraudcounts)


fakercounts = []
try:
    for line in texts:
        fakercounts.append(line.count('faker', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fakercounts)

bullshitcounts = []
try:
    for line in texts:
        bullshitcounts.append(line.count('bullshit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(bullshitcounts)
       
shitcounts = []
try:
    for line in texts:
        shitcounts.append(line.count('shit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(shitcounts)
# Out:
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182
# 4182

# %%
df = pd.DataFrame({ 'lie Count':liecounts, 
                    'flop Count':flopcounts, 
                    'joke Counts':jokecounts, 
                    "credibility Counts":credcounts,
                    "accuracy":accuracycounts ,
                    "disbelief":disbeliefcounts , 
                    "discredit":discreditcounts ,
                    "reject":rejectcounts ,
                    "false":falsehoodcounts ,
                    "imposter":impostercounts ,
                    "fake":fakecounts ,
                    "FALSE":FALSEcounts ,
                    "insincere":insincerecounts ,
                    "deceive":deceivecounts ,
                    "not genuine":notgenuinecounts ,
                    "not true":nottruecounts ,
                    "undependable": undependablecounts,
                    "unreliable": unreliablecounts,
                    "prevarication": prevaricationcounts,
                    "bust": bustcounts,
                    "gag": gagcounts ,
                    "credibleness": crediblenesscounts,
                    "truth": truthcounts,
                    "falsity": falsitycounts,
                    "impostor": impostorcounts,
                    "faux": fauxcounts,
                    "sham": shamcounts,
                    "lead on":leadoncounts ,
                    "fizzle": fizzlecounts,
                    "laugh": laughcounts,
                    "believability": believabilitycounts,
                    "untruth": untruthcounts,
                    "pretender": pretendercounts,
                    "imitation": imitationcounts,
                    "postiche": postichecounts,
                    "delude": deludecounts,
                    "simulated": simulatedcounts,
                    "jape": japecounts,
                    "fraud": fraudcounts,
                    "faker": fakercounts,
                    "bullshit":bullshitcounts ,
                    "shit":shitcounts }, index=times)

# %%
sumdf = df.groupby(df.index).sum()

# %%
sumdf.plot(kind='bar')
print sumdf
# Out:
#             FALSE  accuracy  believability  bullshit  bust  \
# 2015-07-01      0         0              0         0     0
# 2015-07-02      0         0              0         0     0
# 2015-07-06      0         0              0         0     0
# 2015-07-07      0         0              0         0     0
# 2015-07-08      0         0              0         0     0
# 2015-07-09      0         0              0         0     0
# 2015-07-11      0         0              0         0     0
# 2015-07-13      0         0              0         0     0
# 2015-07-15      0         0              0         0     0
# 2015-07-18      0         0              0         0     0
# 2015-07-19      0         0              0         0     0
# 2015-07-20      0         0              0         0     0
# 2015-07-21      0         0              0         0     0
# 2015-07-22      0         0              0         0     0
# 2015-07-23      0         0              0         0     0
# ...

# %%
df2 =df.groupby([df.index]).sum()

# %%
df2.plot(kind='bar')

# %%
df2['e'] = df2.sum(axis=1)

# %%
print df2['e']
# Out:
# 2015-07-01      0
# 2015-07-02      0
# 2015-07-06      0
# 2015-07-07      0
# 2015-07-08      0
# 2015-07-09      0
# 2015-07-11      0
# 2015-07-13      0
# 2015-07-15      0
# 2015-07-18      0
# 2015-07-19      0
# 2015-07-20      1
# 2015-07-21      1
# 2015-07-22      0
# 2015-07-23      1
# 2015-07-24      4
# 2015-07-25      5
# 2015-07-26     25
# 2015-07-27    101
# 2015-07-28     94
# 2015-07-29    267
# 2015-07-30     75
# 2015-07-31     21
# Name: e, dtype: int64

# %%
df2['e'].plot(kind='bar')

#This is the graph of all the them into one variable

# %%
#Calm

# %%
import re

acounts = []
try:
    for line in texts:
        acounts.append(line.count('calm', re.IGNORECASE))
        
except ValueError as detail:  
    print 'fail?', detail
    
print len(acounts)

flopcounts = []
try:
    for line in texts:
        flopcounts.append(line.count('flop', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(flopcounts)



jokecounts = []
try:
    for line in texts:
        jokecounts.append(line.count('joke', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(jokecounts)

credcounts = []
try:
    for line in texts:
        credcounts.append(line.count('credibility', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(credcounts)
accuracycounts = []
try:
    for line in texts:
        accuracycounts.append(line.count('accuracy', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(accuracycounts)
disbeliefcounts = []
try:
    for line in texts:
        disbeliefcounts.append(line.count('disbelief', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(disbeliefcounts)
discreditcounts = []
try:
    for line in texts:
        discreditcounts.append(line.count('discredit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(discreditcounts)
rejectcounts = []
try:
    for line in texts:
        rejectcounts.append(line.count('reject', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(rejectcounts)
falsehoodcounts = []
try:
    for line in texts:
        falsehoodcounts.append(line.count('falsehood', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(falsehoodcounts)
impostercounts = []
try:
    for line in texts:
        impostercounts.append(line.count('imposter', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(impostercounts)
fakecounts = []
try:
    for line in texts:
        fakecounts.append(line.count('fake', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fakecounts)
FALSEcounts = []
try:
    for line in texts:
        FALSEcounts.append(line.count('FALSE', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(FALSEcounts)
insincerecounts = []
try:
    for line in texts:
        insincerecounts.append(line.count('insincere', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(insincerecounts)
deceivecounts = []
try:
    for line in texts:
        deceivecounts.append(line.count('deceive', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(deceivecounts)
notgenuinecounts = []
try:
    for line in texts:
        notgenuinecounts.append(line.count('not genuine', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(notgenuinecounts)
nottruecounts = []
try:
    for line in texts:
        nottruecounts.append(line.count('not true', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(nottruecounts)
undependablecounts = []
try:
    for line in texts:
        undependablecounts.append(line.count('undependable', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(undependablecounts)
unreliablecounts = []
try:
    for line in texts:
        unreliablecounts.append(line.count('unreliable', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(unreliablecounts)
prevaricationcounts = []
try:
    for line in texts:
        prevaricationcounts.append(line.count('prevarication', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(prevaricationcounts)
bustcounts = []
try:
    for line in texts:
        bustcounts.append(line.count('bust', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(bustcounts)
gagcounts = []
try:
    for line in texts:
        gagcounts.append(line.count('gag', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(gagcounts)
crediblenesscounts = []
try:
    for line in texts:
        crediblenesscounts.append(line.count('credibleness', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(crediblenesscounts)

truthcounts = []
try:
    for line in texts:
        truthcounts.append(line.count('truth', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(truthcounts)

falsitycounts = []
try:
    for line in texts:
        falsitycounts.append(line.count('falsity', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(falsitycounts)

impostorcounts = []
try:
    for line in texts:
        impostorcounts.append(line.count('impostor', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(impostorcounts)

fauxcounts = []
try:
    for line in texts:
        fauxcounts.append(line.count('faux', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fauxcounts)

shamcounts = []
try:
    for line in texts:
        shamcounts.append(line.count('sham', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(shamcounts)

leadoncounts = []
try:
    for line in texts:
        leadoncounts.append(line.count('lead on', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(leadoncounts)

fizzlecounts = []
try:
    for line in texts:
        fizzlecounts.append(line.count('fizzle', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fizzlecounts)

laughcounts = []
try:
    for line in texts:
        laughcounts.append(line.count('laugh', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(laughcounts)

believabilitycounts = []
try:
    for line in texts:
        believabilitycounts.append(line.count('believability', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(believabilitycounts)

untruthcounts = []
try:
    for line in texts:
        untruthcounts.append(line.count('untruth', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(untruthcounts)

pretendercounts = []
try:
    for line in texts:
        pretendercounts.append(line.count('pretender', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(pretendercounts)

imitationcounts = []
try:
    for line in texts:
        imitationcounts.append(line.count('imitation', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(imitationcounts)

postichecounts = []
try:
    for line in texts:
        postichecounts.append(line.count('postiche', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(postichecounts)

deludecounts = []
try:
    for line in texts:
        deludecounts.append(line.count('delude', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(deludecounts)

simulatedcounts = []
try:
    for line in texts:
        simulatedcounts.append(line.count('simulated', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(simulatedcounts)

japecounts = []
try:
    for line in texts:
        japecounts.append(line.count('jape', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(japecounts)

fraudcounts = []
try:
    for line in texts:
        fraudcounts.append(line.count('fraud', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fraudcounts)


fakercounts = []
try:
    for line in texts:
        fakercounts.append(line.count('faker', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(fakercounts)

bullshitcounts = []
try:
    for line in texts:
        bullshitcounts.append(line.count('bullshit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(bullshitcounts)
       
shitcounts = []
try:
    for line in texts:
        shitcounts.append(line.count('shit', re.IGNORECASE))
    
except ValueError as detail:  
    print 'fail?', detail
    
print len(shitcounts)
